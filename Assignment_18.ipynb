# %% [markdown]
# <a href="https://colab.research.google.com/github/narajarapu/python102/blob/main/Assignment_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from collections import Counter

# Dummy list of stop words
stop_words = ["the", "a", "an", "in", "he", "she", "her"]

def get_text_content(abcd_id):
    response = requests.get(f"https://abcd2.projectabcd.com/api/getinfo.php?id={abcd_id}")
    return response.text

def generate_frequency_table(abcd_ids, top_n, exclude_stop_words=False):
    word_freq = Counter()
    for abcd_id in abcd_ids:
        text = get_text_content(abcd_id)
        words = text.split()
        if exclude_stop_words:
            words = [word for word in words if word.lower() not in stop_words]
        word_freq.update(words)
    top_n_words = word_freq.most_common(top_n)
    return top_n_words

def display_frequency_table(frequency_table):
    print("Top N words and their frequencies:")
    for word, frequency in frequency_table:
        print(f"{word}: {frequency}")

def main():
    abcd_ids = [711, 733, 523, 542, 731, 763, 669, 739, 690, 742, 724, 112, 668, 714, 671, 32, 722, 434, 713, 751, 760, 102, 654, 695, 762, 470, 33, 432, 429, 265, 673, 111, 588, 734, 692, 477, 518, 720, 445, 437, 752, 206, 670, 544, 491, 737, 685, 492, 53, 676, 575, 469, 183, 717, 665, 715, 410, 425, 430, 586, 769, 235, 462, 741, 524, 718, 758, 465, 745, 520, 431, 721, 171, 484, 759, 672, 433, 749, 502, 756, 747, 757, 26, 765, 667]
    top_n = 10
    frequency_table = generate_frequency_table(abcd_ids, top_n)
    display_frequency_table(frequency_table)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-77f88ffebe1b> in <cell line: 33>()
#      32
#      33 if __name__ == "__main__":
# ---> 34     main()
#
# <ipython-input-2-77f88ffebe1b> in main()
#      28     abcd_ids = [711, 733, 523, 542, 731, 763, 669, 739, 690, 742, 724, 112, 668, 714, 671, 32, 722, 434, 713, 751, 760, 102, 654, 695, 762, 470, 33, 432, 429, 265, 673, 111, 588, 734, 692, 477, 518, 720, 445, 437, 752, 206, 670, 544, 491, 737, 685, 492, 53, 676, 575, 469, 183, [0;...
#      29     top_n = 10
# ---> 30     frequency_table = generate_frequency_table(abcd_ids, top_n)
#      31     display_frequency_table(frequency_table)
#      32
#
# <ipython-input-2-77f88ffebe1b> in generate_frequency_table(abcd_ids, top_n, exclude_stop_words)
#      12     word_freq = Counter()
#      13     for abcd_id in abcd_ids:
# ...
